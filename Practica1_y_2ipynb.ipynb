# %% [markdown]
# <a href="https://colab.research.google.com/github/PonchglezITD/Estadistica/blob/main/Practica1_y_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# probabilidad y estadistica:
# Unidad 1.
#
# Practica 1 y 2. Estadística descriptiva básica e Histogramas
#
# Angel Alfonso Gonzalez García
#
#  José Gabriel Rodríguez Rivas

# %%
from statistics import *
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print (grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
type(grupoa)
# Out:
# list

# %%
promedio= sum(grupoa)/len(grupoa)
print (promedio)
# Out:
# 75.33333333333333

# %%
promedio2=mean(grupoa)
print (promedio2)
# Out:
# 75.33333333333333

# %%
mediana=median(grupoa)
print (mediana)
# Out:
# 76.5

# %%
moda=mode(grupoa)
print (moda)
# Out:
# 70

# %%
moda2=multimode(grupoa)
print (moda2)
# Out:
# [70, 100]

# %% [markdown]
# Ejemplo 2: Tiempos de 100 metros de 12 alumnos

# %%
tiempos100mts=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.1,17.2]
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("El tiempo promedio de los corredores es →" , mean(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es → 17.322

# %%
mediana=median(tiempos100mts)
print ("La media de tiempo de los corredores es →",mediana)
# Out:
# La media de tiempo de los corredores es → 17.2

# %%
moda=mode(tiempos100mts)
print ("La moda de tiempo de los corredores es →",moda)
# Out:
# La moda de tiempo de los corredores es → 15.1

# %%
multimodas=multimode(tiempos100mts)
print ("Las modas de tiempo de los corredores son →",multimodas)
# Out:
# Las modas de tiempo de los corredores son → [15.1, 17.2]

# %% [markdown]
# Ejemplo 3:Histograma de 2 grupos

# %%
import random

# %%
fabrica1=[]
for i in range(100):
 numero_aleatorio = round(random.uniform(50,100),2)
 fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [57.19, 58.18, 93.09, 98.97, 86.11, 64.02, 78.33, 93.95, 53.34, 74.99, 91.46, 92.14, 97.04, 70.68, 59.77, 93.22, 86.0, 93.83, 86.76, 72.39, 97.69, 79.35, 61.55, 58.12, 58.15, 71.53, 57.01, 56.81, 97.48, 98.75, 98.74, 85.11, 80.07, 79.43, 72.84, 92.7, 75.87, 87.84, 78.91, 55.87, 91.27, 76.97, 77.31, 60.65, 62.45, 85.18, 73.29, 91.57, 52.72, 57.9, 86.2, 55.35, 80.23, 71.2, 86.27, 98.16, 70.31, 78.44, 70.79, 54.45, 57.76, 59.64, 65.19, 94.35, 90.94, 76.33, 51.93, 54.71, 53.37, 54.13, 82.51, 67.74, 64.83, 90.66, 63.76, 98.75, 50.03, 73.31, 80.56, 58.05, 91.71, 61.3, 71.57, 87.64, 89.14, 83.88, 74.76, 59.54, 90.96, 50.9, 60.52, 54.9, 54.89, 73.95, 85.68, 50.02, 87.26, 57.82, 71.38, 99.61]

# %%
fabrica2=[]
for i in range(100):
 numero_aleatorio2 = round(random.uniform(50,100),2)
 fabrica2.append(numero_aleatorio2)
print (fabrica2)
# Out:
# [73.5, 59.63, 55.32, 91.66, 84.62, 96.41, 93.58, 95.12, 73.63, 61.7, 64.4, 60.77, 57.34, 82.02, 84.62, 67.56, 60.49, 64.51, 70.32, 64.12, 96.65, 80.9, 94.74, 67.92, 88.06, 93.18, 77.87, 79.93, 50.07, 91.02, 97.59, 69.79, 85.77, 57.19, 90.77, 62.1, 72.73, 86.62, 94.01, 64.06, 95.28, 54.11, 86.41, 71.61, 85.59, 66.5, 94.06, 63.64, 89.47, 51.37, 83.3, 56.97, 65.05, 81.17, 58.28, 77.7, 86.31, 86.08, 77.6, 69.72, 73.26, 72.36, 73.82, 76.25, 98.83, 59.83, 78.11, 50.65, 91.93, 64.94, 65.23, 88.71, 89.32, 78.2, 74.0, 64.79, 67.74, 90.47, 53.1, 74.65, 69.39, 55.45, 95.27, 68.9, 51.46, 68.1, 65.46, 81.65, 76.98, 57.79, 57.14, 70.72, 71.86, 66.93, 83.84, 87.72, 88.96, 93.14, 53.21, 53.79]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion de la fabrica 2')

# %%
media1=mean(fabrica1)
mediana1=median(fabrica1)
mod1=mode(fabrica1)

print("Valores Fabrica1")
print("Media:",media1)
print("Mediana:",mediana1)
print("Moda:",mod1)
# Out:
# Valores Fabrica1
# Media: 74.7197
# Mediana: 74.875
# Moda: 98.75

# %%
media2=mean(fabrica2)
mediana2=median(fabrica2)
mod2=mode(fabrica2)

print("Valores Fabrica2")
print("Media:",media2)
print("Mediana:",mediana2)
print("Moda:",mod2)
# Out:
# Valores Fabrica2
# Media: 74.66460000000001
# Mediana: 73.565
# Moda: 84.62

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(9,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(mod1, color='y', linestyle='dashed', linewidth=2, label= 'Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(mod2, color='y', linestyle='dashed', linewidth=2, label= 'Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/PonchglezITD/Estadistica/blob/main/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica:
# Unidad 1
#  practica 3. Maximo,minimo,rango y dispersión de datos
#
# Angel Alfonso Gonzalez García
#
#  José Gabriel Rodríguez Rivas

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1=[]
for i in range(100):
    numero_aleatorio=round(random.uniform(50,100),2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [76.3, 70.48, 90.08, 70.03, 95.93, 83.13, 65.94, 95.91, 91.69, 77.13, 59.48, 68.5, 73.06, 57.26, 61.78, 57.47, 67.17, 77.21, 82.65, 96.42, 80.33, 62.17, 57.59, 96.16, 60.7, 52.97, 85.53, 63.29, 84.31, 61.59, 66.76, 87.11, 72.32, 60.15, 66.42, 51.79, 56.16, 97.51, 62.44, 62.74, 65.25, 93.03, 63.37, 72.16, 96.99, 83.31, 90.33, 68.84, 76.04, 81.31, 95.44, 64.46, 93.25, 90.95, 52.91, 64.63, 62.27, 53.86, 60.08, 78.27, 94.41, 87.59, 59.03, 89.29, 51.33, 57.87, 77.44, 88.78, 64.67, 85.09, 84.86, 56.15, 70.91, 73.14, 74.96, 65.53, 52.66, 83.92, 66.97, 72.99, 59.01, 75.07, 54.88, 50.88, 86.51, 87.87, 70.95, 91.97, 89.33, 70.5, 60.49, 54.7, 83.46, 71.86, 76.71, 58.79, 73.74, 53.47, 77.89, 74.84]

# %%
fabrica2=[]
for i in range(100):
    numero_aleatorio2=round(random.uniform(50,100),2)
    fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [94.92, 96.59, 75.79, 61.62, 91.66, 77.32, 88.8, 66.28, 67.78, 59.86, 82.91, 79.26, 74.12, 56.3, 90.39, 84.55, 90.96, 80.97, 69.33, 88.35, 67.23, 64.81, 99.74, 51.13, 87.21, 53.61, 62.73, 98.13, 60.09, 99.12, 65.51, 90.68, 55.01, 88.88, 54.73, 94.22, 78.35, 97.38, 90.83, 62.36, 54.12, 59.4, 95.85, 92.53, 98.34, 58.22, 55.53, 82.88, 72.6, 73.91, 53.08, 55.5, 63.68, 78.57, 97.4, 74.73, 72.16, 53.13, 58.31, 69.77, 84.9, 74.86, 95.93, 64.13, 89.12, 60.46, 50.83, 71.69, 85.87, 77.34, 51.25, 66.71, 63.55, 50.89, 75.1, 63.74, 69.88, 89.92, 60.93, 51.62, 61.31, 87.05, 76.56, 74.62, 89.33, 78.54, 57.98, 83.11, 63.07, 53.84, 62.32, 74.81, 86.22, 61.37, 53.26, 90.94, 88.63, 56.71, 54.91, 92.63]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("estadistica descriptiva de la fabrica 1\n", "media =", mediana1,
    "\n mediana= ", mediana1, "\n moda = ", moda1, "\n moda = ", moda1, "\n maximo = ", maximo1,
      "\n minimo = ", minimo1, "\n rango = ",rango1)
# Out:
# estadistica descriptiva de la fabrica 1
#  media = 72.00999999999999
#  mediana=  72.00999999999999
#  moda =  76.3
#  moda =  76.3
#  maximo =  97.51
#  minimo =  50.88
#  rango =  46.63

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("estadistica descriptiva de la fabrica 2\n", "media =", mediana2,
    "\n mediana= ", mediana2, "\n moda = ", moda2, "\n moda = ", moda2, "\n maximo = ", maximo2,
      "\n minimo = ", minimo2, "\n rango = ",rango2)
# Out:
# estadistica descriptiva de la fabrica 2
#  media = 74.015
#  mediana=  74.015
#  moda =  94.92
#  moda =  94.92
#  maximo =  99.74
#  minimo =  50.83
#  rango =  48.91

# %%
desviacion_estandar_fabrica1=stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 13.54060512799643

# %%
desviacion_estandar_fabrica2=stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 14.974029597063623

# %%
plt. figure(figsize = (8,6) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt. figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

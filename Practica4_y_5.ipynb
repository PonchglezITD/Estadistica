# %% [markdown]
# <a href="https://colab.research.google.com/github/PonchglezITD/Estadistica/blob/main/Practica4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica
# :Unidad 1
#  practica 4. Tabla de frecuencias y regla de Sturge
#
# Angel Alfonso Gonzalez Garcia
#
#  José Gabriel Rodríguez Rivas

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio=random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [43, 48, 59, 56, 29, 27, 38, 39, 28, 27, 30, 62, 68, 28, 44, 22, 60, 64, 51, 68, 21, 40, 68, 48, 65, 65, 21, 67, 20, 65, 30, 26, 54, 65, 23, 34, 29, 53, 56, 38, 32, 59, 63, 49, 22, 44, 59, 20, 62, 31, 67, 28, 37, 45, 34, 53, 35, 34, 24, 47, 36, 25, 49, 56, 19, 51, 39, 44, 44, 57, 24, 31, 32, 60, 37, 56, 59, 29, 68, 65, 44, 22, 45, 26, 69, 64, 32, 54, 26, 52, 18, 26, 63, 34, 39, 59, 57, 60, 58, 69]

# %%
import pandas as pd

# %%
df=pd.DataFrame(edades,columns=['Edades'])
df.head()
# Out:
#    Edades
# 0      43
# 1      48
# 2      59
# 3      56
# 4      29

# %%
tabla_frecuencias=df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns=['Edades','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edades')
tabla_frecuencias
# Out:
#     Edades  Frecuencia
# 33      18           1
# 36      19           1
# 22      20           2
# 25      21           2
# 11      22           3
# 41      23           1
# 13      24           2
# 35      25           1
# 3       26           4
# 31      27           2
# 10      28           3
# 8       29           3
# 29      30           2
# 18      31           2
# 7       32           3
# 5       34           4
# 40      35           1
# 38      36           1
# 19      37           2
# 30      38           2
# 9       39           3
# 42      40           1
# 37      43           1
# 2       44           5
# 32      45           2
# 39      47           1
# 16      48           2
# 17      49           2
# 21      51           2
# 34      52           1
# 14      53           2
# 20      54           2
# 4       56           4
# 24      57           2
# 43      58           1
# 0       59           5
# 12      60           3
# 28      62           2
# 15      63           2
# 27      64           2
# 1       65           5
# 23      67           2
# 6       68           4
# 26      69           2

# %%
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa
# 33      18           1           0.01
# 36      19           1           0.01
# 22      20           2           0.02
# 25      21           2           0.02
# 11      22           3           0.03
# 41      23           1           0.01
# 13      24           2           0.02
# 35      25           1           0.01
# 3       26           4           0.04
# 31      27           2           0.02
# 10      28           3           0.03
# 8       29           3           0.03
# 29      30           2           0.02
# 18      31           2           0.02
# 7       32           3           0.03
# 5       34           4           0.04
# 40      35           1           0.01
# 38      36           1           0.01
# 19      37           2           0.02
# 30      38           2           0.02
# 9       39           3           0.03
# 42      40           1           0.01
# 37      43           1           0.01
# 2       44           5           0.05
# 32      45           2           0.02
# 39      47           1           0.01
# 16      48           2           0.02
# 17      49           2           0.02
# 21      51           2           0.02
# 34      52           1           0.01
# 14      53           2           0.02
# 20      54           2           0.02
# 4       56           4           0.04
# 24      57           2           0.02
# 43      58           1           0.01
# 0       59           5           0.05
# 12      60           3           0.03
# 28      62           2           0.02
# 15      63           2           0.02
# 27      64           2           0.02
# 1       65           5           0.05
# 23      67           2           0.02
# 6       68           4           0.04
# 26      69           2           0.02

# %%
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa  Frec Porcentual
# 33      18           1           0.01              1.0
# 36      19           1           0.01              1.0
# 22      20           2           0.02              2.0
# 25      21           2           0.02              2.0
# 11      22           3           0.03              3.0
# 41      23           1           0.01              1.0
# 13      24           2           0.02              2.0
# 35      25           1           0.01              1.0
# 3       26           4           0.04              4.0
# 31      27           2           0.02              2.0
# 10      28           3           0.03              3.0
# 8       29           3           0.03              3.0
# 29      30           2           0.02              2.0
# 18      31           2           0.02              2.0
# 7       32           3           0.03              3.0
# 5       34           4           0.04              4.0
# 40      35           1           0.01              1.0
# 38      36           1           0.01              1.0
# 19      37           2           0.02              2.0
# 30      38           2           0.02              2.0
# 9       39           3           0.03              3.0
# 42      40           1           0.01              1.0
# 37      43           1           0.01              1.0
# 2       44           5           0.05              5.0
# 32      45           2           0.02              2.0
# 39      47           1           0.01              1.0
# 16      48           2           0.02              2.0
# 17      49           2           0.02              2.0
# 21      51           2           0.02              2.0
# 34      52           1           0.01              1.0
# 14      53           2           0.02              2.0
# 20      54           2           0.02              2.0
# 4       56           4           0.04              4.0
# 24      57           2           0.02              2.0
# 43      58           1           0.01              1.0
# 0       59           5           0.05              5.0
# 12      60           3           0.03              3.0
# 28      62           2           0.02              2.0
# 15      63           2           0.02              2.0
# 27      64           2           0.02              2.0
# 1       65           5           0.05              5.0
# 23      67           2           0.02              2.0
# 6       68           4           0.04              4.0
# 26      69           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 33      18           1           0.01              1.0               1
# 36      19           1           0.01              1.0               2
# 22      20           2           0.02              2.0               4
# 25      21           2           0.02              2.0               6
# 11      22           3           0.03              3.0               9
# 41      23           1           0.01              1.0              10
# 13      24           2           0.02              2.0              12
# 35      25           1           0.01              1.0              13
# 3       26           4           0.04              4.0              17
# 31      27           2           0.02              2.0              19
# 10      28           3           0.03              3.0              22
# 8       29           3           0.03              3.0              25
# 29      30           2           0.02              2.0              27
# 18      31           2           0.02              2.0              29
# 7       32           3           0.03              3.0              32
# 5       34           4           0.04              4.0              36
# 40      35           1           0.01              1.0              37
# 38      36           1           0.01              1.0              38
# 19      37           2           0.02              2.0              40
# 30      38           2           0.02              2.0              42
# 9       39           3           0.03              3.0              45
# 42      40           1           0.01              1.0              46
# 37      43           1           0.01              1.0              47
# 2       44           5           0.05              5.0              52
# 32      45           2           0.02              2.0              54
# 39      47           1           0.01              1.0              55
# 16      48           2           0.02              2.0              57
# 17      49           2           0.02              2.0              59
# 21      51           2           0.02              2.0              61
# 34      52           1           0.01              1.0              62
# 14      53           2           0.02              2.0              64
# 20      54           2           0.02              2.0              66
# 4       56           4           0.04              4.0              70
# 24      57           2           0.02              2.0              72
# 43      58           1           0.01              1.0              73
# 0       59           5           0.05              5.0              78
# 12      60           3           0.03              3.0              81
# 28      62           2           0.02              2.0              83
# 15      63           2           0.02              2.0              85
# 27      64           2           0.02              2.0              87
# 1       65           5           0.05              5.0              92
# 23      67           2           0.02              2.0              94
# 6       68           4           0.04              4.0              98
# 26      69           2           0.02              2.0             100

# %% [markdown]
# Regla de sturge

# %%
import math

# %%
print(edades)
# Out:
# [43, 48, 59, 56, 29, 27, 38, 39, 28, 27, 30, 62, 68, 28, 44, 22, 60, 64, 51, 68, 21, 40, 68, 48, 65, 65, 21, 67, 20, 65, 30, 26, 54, 65, 23, 34, 29, 53, 56, 38, 32, 59, 63, 49, 22, 44, 59, 20, 62, 31, 67, 28, 37, 45, 34, 53, 35, 34, 24, 47, 36, 25, 49, 56, 19, 51, 39, 44, 44, 57, 24, 31, 32, 60, 37, 56, 59, 29, 68, 65, 44, 22, 45, 26, 69, 64, 32, 54, 26, 52, 18, 26, 63, 34, 39, 59, 57, 60, 58, 69]

# %%
df=pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     43
# 1     48
# 2     59
# 3     56
# 4     29
# ..   ...
# 95    59
# 96    57
# 97    60
# 98    58
# 99    69
#
# [100 rows x 1 columns]

# %%
n=len(edades)
k=int(1+math.log2(100))
print("valor de n:",n,"\nNumero de intervalos:",k )
# Out:
# valor de n: 100
# Numero de intervalos: 7

# %%
tabla_frecuencias=pd.cut(df['Edad'],bins=k,include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns=['Clase','Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0  (25.286, 32.571]    19
# 1    (61.714, 69.0]    19
# 2  (54.429, 61.714]    15
# 3  (17.948, 25.286]    13
# 4  (32.571, 39.857]    13
# 5  (47.143, 54.429]    11
# 6  (39.857, 47.143]    10

# %%
tabla_frecuencias=tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 3  (17.948, 25.286]    13
# 0  (25.286, 32.571]    19
# 4  (32.571, 39.857]    13
# 6  (39.857, 47.143]    10
# 5  (47.143, 54.429]    11
# 2  (54.429, 61.714]    15
# 1    (61.714, 69.0]    19

# %%
tabla_frecuencias['Frec Rel']=tabla_frecuencias['Frec']/n
tabla_frecuencias['Frec Por']=tabla_frecuencias['Frec']/n*100
tabla_frecuencias['Frec Ac']=tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac']=tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['frec por Ac']=tabla_frecuencias['Frec Por'].cumsum()
print(tabla_frecuencias)
# Out:
#               Clase  Frec  Frec Rel  Frec Por  Frec Ac  Frec Rel Ac  \
# 3  (17.948, 25.286]    13      0.13      13.0       13         0.13
# 0  (25.286, 32.571]    19      0.19      19.0       32         0.32
# 4  (32.571, 39.857]    13      0.13      13.0       45         0.45
# 6  (39.857, 47.143]    10      0.10      10.0       55         0.55
# 5  (47.143, 54.429]    11      0.11      11.0       66         0.66
# 2  (54.429, 61.714]    15      0.15      15.0       81         0.81
# 1    (61.714, 69.0]    19      0.19      19.0      100         1.00
#
#    frec por Ac
# 3         13.0
# 0         32.0
# 4         45.0
# 6         55.0
# 5         66.0
# 2         81.0
# 1        100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5)
plt.title('Histograma de edades')
# Out:
# Text(0.5, 1.0, 'Histograma de edades')

# %%
plt.hist(df['Edad'],bins=k,alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica
# :Unidad 1
#  practica 5 Diagramas de Cajas y bigotes.
#
# Angel Alfonso Gonzalez Garcia
#
#  José Gabriel Rodríguez Rivas

# %%
import random
edades2=[]
for i in range(100):
  numero_aleatorio2=random.randint(20, 87)
  edades2.append(numero_aleatorio2)
print(edades2)
# Out:
# [36, 56, 42, 81, 66, 59, 80, 28, 75, 55, 35, 81, 57, 74, 30, 84, 38, 64, 25, 65, 84, 27, 81, 63, 55, 40, 79, 74, 69, 80, 75, 60, 22, 70, 78, 22, 86, 55, 84, 35, 55, 74, 84, 83, 45, 48, 43, 49, 53, 74, 65, 87, 65, 78, 36, 47, 26, 58, 50, 33, 46, 68, 67, 79, 22, 20, 48, 25, 65, 80, 31, 40, 40, 64, 21, 81, 37, 29, 73, 79, 57, 40, 70, 82, 25, 73, 78, 62, 63, 33, 52, 69, 44, 35, 63, 46, 83, 64, 40, 59]

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title('Edades encuesta 1')
bplot2=ax2.boxplot(edades2,
                   vert=True,
                   patch_artist=True)
ax2.set_title('Edades encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title('Edades encuesta 1')
bplot2=ax2.boxplot(edades2,
                   vert=True,
                   patch_artist=True)
ax2.set_title('Edades encuesta 2')
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/PonchglezITD/Estadistica/blob/main/Practica0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistíca
#
# ##Unidad 1
# Práctica #0 "Introducción Python"
#
# Grupo 2Y
#
# Alumno: Angel Alfonso Gonzalez García
#
# Docente: Dr. José Gabriel Rodríguez Rivas
# ![image.png](data:image/png;base64,...)

# %%
a = 10
b = 15
if a < b:
    print(a,"es menor que ",b)
else:
    print (b," es menor que ",a)
# Out:
# 10 es menor que  15

# %%
for i in range(10):
 print(i)
 print("Dentro del for")
print("Fuera del for")
# Out:
# 0
# Dentro del for
# 1
# Dentro del for
# 2
# Dentro del for
# 3
# Dentro del for
# 4
# Dentro del for
# 5
# Dentro del for
# 6
# Dentro del for
# 7
# Dentro del for
# 8
# Dentro del for
# 9
# Dentro del for
# Fuera del for

# %%
x = 10
print(x)

# %%
#COMENTARIO
x = "Hola Hola"
print(x)
